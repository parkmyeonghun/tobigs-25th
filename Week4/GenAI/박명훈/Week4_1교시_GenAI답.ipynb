# %% [markdown]
# # 🐻‍❄️ 투빅스 정규세션 4주차 1교시 Generative AI 코드 과제 🐻‍❄️

# %% [markdown]
# 이번 과제에서는 VAE 모델과 DCGAN 모델을 직접 구현 및 학습하여 이미지를 생성해보고, 그 결과를 비교해보겠습니다.
#
# - **VAE(Variational AutoEncoder)**: 입력 데이터를 저차원의 잠재 공간(latent space)으로 압축한 뒤, 이 공간의 확률 분포를 기반으로 다시 원본 데이터를 복원 및 생성하도록 하는 모델
#
# - **GAN(Generative Adversarial Network)**: 생성자(Generator)와 판별자(Discriminator)라는 두 개의 네트워크가 서로 경쟁하며 학습하는 모델
#   * Generator: Random noise를 입력받아 진짜(Real) 같은 가짜(Fake) 데이터를 생성 (=위조지폐범)
#   * Discriminator: 입력받은 데이터가 Real인지 Fake인지 구분 (=경찰)
#
# - **DCGAN (Deep Convolutional GAN)**: 기존 GAN은 단순한 MLP(Multi-Layer Perceptron) 구조인 반면, DCGAN은 이를 Convolutional 구조로 확장하여 이미지의 생성 성능을 향상시킨 모델

# %% [markdown]
# ### **모듈 임포트 및 디바이스 설정**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### **데이터셋 준비 (MNIST dataset)**

# %%
batch_size = 128
epochs = 30

transform = transforms.Compose([
    transforms.ToTensor()
])

dataset = torchvision.datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# train / val split
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(
    dataset,
    [train_size, val_size]
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 14.3MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 340kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.10MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 14.8MB/s]

# %% [markdown]
# ## **VAE(Variational AutoEncoder) 모델 정의 및 학습**
#
# * Encoder: 입력 데이터 x를 받아 잠재 공간(Latent Space)의 파라미터를 추출
#   * 고차원의 입력데이터를 저차원의 평균과 로그 분산으로 변환
#     * 💡 빈칸 채우기 hint) `self.fc1`을 거쳐 특징을 추출한 뒤, 두 개의 서로 다른 선형 레이어를 통해 각각 평균과 로그 분산을 계산
#
# * Latent Space & Reparameterization
#   * 잠재 변수 z를 직접 고정된 값으로 뽑는 것이 아니라, encoder가 만든 분포(평균, 로그 분산)에서 샘플링함
#   * Reparameterization Trick: backpropagation는 샘플링 연산을 통과할 수 없다는 문제를 해결하기 위해 샘플링 과정을 미분 가능한 형태로 만들기 위한 수식
#
# * Decoder
#   * 샘플링된 잠재 변수 z를 다시 원래의 입력 데이터 차원으로 복원

# %% [markdown]
# ![image_vae.png](data:image/png;base64,...)

# %% [markdown]
# 참고 코드: https://github.com/NoviceStone/VAE/blob/master/models.py

# %%
class VAE(nn.Module):

    def __init__(self, input_size=784, hidden_size=400, latent_size=20, data_type="binary"):
        super(VAE, self).__init__()

        # Encoder: layers
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc21 = nn.Linear(hidden_size, latent_size)  # 평균(mu)
        self.fc22 = nn.Linear(hidden_size, latent_size)  # 로그 분산(logvar)

        # Decoder: layers
        self.fc3 = nn.Linear(latent_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, input_size)

        self.data_type = data_type

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        mean = self.fc21(h1) # 🤔 빈칸을 채워주세요
        log_var = self.fc22(h1) # 🤔 빈칸을 채워주세요
        return mean, log_var

    @staticmethod
    def reparameterize(mean, log_var):

        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)

        z = mean + std * eps
        return z

    def decode(self, z):

        h3 = F.relu(self.fc3(z))

        logits = self.fc4(h3)
        probs = torch.sigmoid(logits)

        return probs

    def forward(self, x):

        x = x.view(-1, 784)

        mu, logvar = self.encode(x)

        z = self.reparameterize(mu, logvar)

        recon = self.decode(z)

        return recon, mu, logvar

# %% [markdown]
# ### **VAE loss (ELBO)**
# * Reconsturction Loss: 복원된 이미지(`recon_x`)가 원본 이미지(`x`)와 얼마나 다른지 측정
# * KL Divergence: 잠재공간의 분포가 표준 정규븐포와 얼마나 다른지 측정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def elbo_loss(x, recon_x, mu, logvar):

    B = x.size(0)

    x = x.view(-1, 784)

    BCE = F.binary_cross_entropy(recon_x, x, reduction='sum') / B # 🤔 빈칸을 채워주세요

    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) / B # 🤔 빈칸을 채워주세요

    total_loss = BCE + KLD # 🤔 빈칸을 채워주세요

    return total_loss

# %% [markdown]
# ## **🙋 [VAE] Question 1**
# VAE의 ELBO Loss에 KL Divergence 항이 포함되는 이유를 설명해주세요.
#
#
#
# *VAE의 ELBO Loss에 KLD 항이 포함되는 이유는 두 가지입니다.
#
# 1. 공간 채우기 (규제): 단순 복원만 하면 잠재 공간에 데이터가 띄엄띄엄 배치되어 빈 공간에서 샘플링하면 깨진 이미지가 나옵니다. KLD는 이 공간을 표준 정규 분포($N(0, 1)$) 형태로 촘촘하고 고르게 모아줍니다.
#
# 2. 생성 능력 부여: 공간이 촘촘해지면 학습 때 보지 못한 지점을 찍어도 그럴듯한 데이터를 생성할 수 있게 됩니다. 즉, '압축기'를 '생성기'로 만드는 핵심 장치입니다.

# %%
vae = VAE().to(device)
optimizer = optim.Adam(vae.parameters(), lr=1e-3)

for epoch in range(epochs):


    # ========== Train ==========
    vae.train()
    train_loss = 0

    for x,_ in train_loader:

        x = x.to(device)

        recon, mu, logvar = vae(x)

        loss = elbo_loss(x,recon, mu, logvar)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    train_loss /= len(train_dataset)


    # ========== Validation ==========
    vae.eval()
    val_loss = 0

    with torch.no_grad():

        for x,_ in val_loader:

            x = x.to(device)

            recon, mu, logvar = vae(x)

            loss = elbo_loss(x, recon, mu, logvar)

            val_loss += loss.item()

    val_loss /= len(val_dataset)

    print(f"[VAE] Epoch {epoch+1}/{epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
# Out:
# [VAE] Epoch 1/30 | Train Loss: 1.3014 | Val Loss: 1.0191
# [VAE] Epoch 2/30 | Train Loss: 0.9641 | Val Loss: 0.9237
# [VAE] Epoch 3/30 | Train Loss: 0.9040 | Val Loss: 0.8892
# [VAE] Epoch 4/30 | Train Loss: 0.8793 | Val Loss: 0.8730
# [VAE] Epoch 5/30 | Train Loss: 0.8642 | Val Loss: 0.8637
# [VAE] Epoch 6/30 | Train Loss: 0.8545 | Val Loss: 0.8523
# [VAE] Epoch 7/30 | Train Loss: 0.8476 | Val Loss: 0.8484
# [VAE] Epoch 8/30 | Train Loss: 0.8420 | Val Loss: 0.8437
# [VAE] Epoch 9/30 | Train Loss: 0.8375 | Val Loss: 0.8393
# [VAE] Epoch 10/30 | Train Loss: 0.8342 | Val Loss: 0.8363
# [VAE] Epoch 11/30 | Train Loss: 0.8312 | Val Loss: 0.8369
# [VAE] Epoch 12/30 | Train Loss: 0.8291 | Val Loss: 0.8317
# [VAE] Epoch 13/30 | Train Loss: 0.8263 | Val Loss: 0.8308
# [VAE] Epoch 14/30 | Train Loss: 0.8245 | Val Loss: 0.8282
# [VAE] Epoch 15/30 | Train Loss: 0.8230 | Val Loss: 0.8269
# [VAE] Epoch 16/30 | Train Loss: 0.8209 | Val Loss: 0.8254
# [VAE] Epoch 17/30 | Train Loss: 0.8196 | Val Loss: 0.8244
# [VAE] Epoch 18/30 | Train Loss: 0.8184 | Val Loss: 0.8232
# [VAE] Epoch 19/30 | Train Loss: 0.8173 | Val Loss: 0.8216
# [VAE] Epoch 20/30 | Train Loss: 0.8157 | Val Loss: 0.8223
# [VAE] Epoch 21/30 | Train Loss: 0.8151 | Val Loss: 0.8213
# [VAE] Epoch 22/30 | Train Loss: 0.8141 | Val Loss: 0.8205
# [VAE] Epoch 23/30 | Train Loss: 0.8131 | Val Loss: 0.8190
# [VAE] Epoch 24/30 | Train Loss: 0.8121 | Val Loss: 0.8185
# [VAE] Epoch 25/30 | Train Loss: 0.8115 | Val Loss: 0.8181
# [VAE] Epoch 26/30 | Train Loss: 0.8103 | Val Loss: 0.8156
# [VAE] Epoch 27/30 | Train Loss: 0.8093 | Val Loss: 0.8157
# [VAE] Epoch 28/30 | Train Loss: 0.8086 | Val Loss: 0.8182
# [VAE] Epoch 29/30 | Train Loss: 0.8081 | Val Loss: 0.8154
# [VAE] Epoch 30/30 | Train Loss: 0.8073 | Val Loss: 0.8126

# %% [markdown]
# **VAE sampling 시각화**

# %%
with torch.no_grad():

    z = torch.randn(64,20).to(device)

    samples = vae.decode(z).view(-1,1,28,28)

    grid = make_grid(samples,8)

plt.imshow(grid.permute(1,2,0).cpu())
plt.title("VAE Samples")
plt.show()

# %% [markdown]
# ## **DCGAN(Deep Convolutional GAN) 모델 정의 및 학습**
# - Weight Initialization
#   - 모델의 가중치는 평균이 0, 표준편차가 0.02인 정규분포로 초기화
#   - 기존 GAN의 학습 불안정성을 줄이기 위해 DCGAN 논문에서 제안한 아이디어
#
# - Generator (생성자)
#   - Transposed Convolution: 저차원의 잠재 벡터를 고해상도 이미지로 확장
#   - Batch Normalization: 각 layer의 출력을 정규화하여 학습의 안정성을 높이고 gradient vanishing 문제를 해결
#   - Activation: 중간 layer에는 ReLU를 통해 빠른 학습을 진행하고, 마지막 layer에는 이미지의 픽셀 값 범위([-1, 1])를 맞추기 위해 Tanh를 사용
#
# - Discriminator (판별자)
#   - Strided Convolution: pooling 대신 stride를 사용하여 특징을 추출
#   - LeakyReLU: 음수 영역에 작은 양수 기울기를 부여하여 Gradient Vanishing 문제를 해결
#   - Activation: 마지막 layer에 sigmoid를 사용하여 real(1)/fake(0) 사이의 확률 값을 출력

# %% [markdown]
# ![The-architecture-of-vanilla-GANs.png](data:image/png;base64,...)

# %% [markdown]
# 참고 코드: https://github.com/Natsu6767/DCGAN-PyTorch/blob/master/dcgan.py

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)) # [-1, 1]
])

dataset = torchvision.datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# train / val split
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(
    dataset,
    [train_size, val_size]
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %%
# weight 초기화 함수

def weights_init(m):

    classname = m.__class__.__name__

    if classname.find("Conv") != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)

    elif classname.find("BatchNorm") != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
latent_size = 20

class Generator(nn.Module):

    def __init__(self):

        super().__init__()

        self.tconv1 = nn.ConvTranspose2d(latent_size,256,7,1,0,bias=False)
        self.bn1 = nn.BatchNorm2d(256)

        self.tconv2 = nn.ConvTranspose2d(256,128,4,2,1,bias=False)
        self.bn2 = nn.BatchNorm2d(128)

        self.tconv3 = nn.ConvTranspose2d(128,64,4,2,1,bias=False)
        self.bn3 = nn.BatchNorm2d(64)

        self.tconv4 = nn.ConvTranspose2d(64,1,3,1,1,bias=False)

    def forward(self,x):

        x = F.relu(self.bn1(self.tconv1(x)))
        x = F.relu(self.bn2(self.tconv2(x)))
        x = F.relu(self.bn3(self.tconv3(x)))

        x = torch.tanh(self.tconv4(x))

        return x

# %%
class Discriminator(nn.Module):

    def __init__(self):

        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=1,out_channels=64,kernel_size=4,stride=2,padding=1,bias=False)

        self.conv2 = nn.Conv2d(64,128,4,2,1,bias=False)
        self.bn2 = nn.BatchNorm2d(128)

        self.conv3 = nn.Conv2d(128,256,4,2,1,bias=False)
        self.bn3 = nn.BatchNorm2d(256)

        self.conv4 = nn.Conv2d(256,1,3,1,0,bias=False)

    def forward(self,x):

        x = F.leaky_relu(self.conv1(x),0.2,True)

        x = F.leaky_relu(self.bn2(self.conv2(x)),0.2,True)

        x = F.leaky_relu(self.bn3(self.conv3(x)),0.2,True)

        x = torch.sigmoid(self.conv4(x))

        return x.view(-1)

# %%
G = Generator().to(device)
D = Discriminator().to(device)

G.apply(weights_init)
D.apply(weights_init)

criterion = nn.BCELoss()

optG = optim.Adam(G.parameters(),0.0002,betas=(0.5,0.999))
optD = optim.Adam(D.parameters(),0.0002,betas=(0.5,0.999))

# %%
for epoch in range(epochs):

    G.train()
    D.train()

    train_lossD = 0
    train_lossG = 0

    for x,_ in train_loader:

        x = x.to(device)

        real = torch.ones(x.size(0)).to(device)
        fake = torch.zeros(x.size(0)).to(device)


        # ========== Train Discriminator ==========

        z = torch.randn(x.size(0),latent_size,1,1).to(device)

        fake_img = G(z)

        loss_real = criterion(D(x), real)
        loss_fake = criterion(D(fake_img.detach()), fake)

        lossD = loss_real + loss_fake

        optD.zero_grad()
        lossD.backward()
        optD.step()


        # ========== Train Generator ==========

        lossG = criterion(D(fake_img), real) # 🤔 빈칸을 채워주세요

        optG.zero_grad()
        lossG.backward()
        optG.step()

        train_lossD += lossD.item()
        train_lossG += lossG.item()

    train_lossD /= len(train_loader)
    train_lossG /= len(train_loader)

    print(f"[DCGAN] Epoch {epoch+1}/{epochs} | Train D Loss {train_lossD:.4f} | Train G Loss {train_lossG:.4f}")
# Out:
# [DCGAN] Epoch 1/30 | Train D Loss 0.8097 | Train G Loss 1.6699
# [DCGAN] Epoch 2/30 | Train D Loss 0.9087 | Train G Loss 1.4430
# [DCGAN] Epoch 3/30 | Train D Loss 0.9740 | Train G Loss 1.3643
# [DCGAN] Epoch 4/30 | Train D Loss 1.0118 | Train G Loss 1.3038
# [DCGAN] Epoch 5/30 | Train D Loss 1.0023 | Train G Loss 1.3337
# [DCGAN] Epoch 6/30 | Train D Loss 0.9975 | Train G Loss 1.3638
# [DCGAN] Epoch 7/30 | Train D Loss 0.9981 | Train G Loss 1.3645
# [DCGAN] Epoch 8/30 | Train D Loss 1.0004 | Train G Loss 1.3739
# [DCGAN] Epoch 9/30 | Train D Loss 0.9849 | Train G Loss 1.4105
# [DCGAN] Epoch 10/30 | Train D Loss 0.9630 | Train G Loss 1.4476
# [DCGAN] Epoch 11/30 | Train D Loss 0.9387 | Train G Loss 1.4825
# [DCGAN] Epoch 12/30 | Train D Loss 0.9317 | Train G Loss 1.5177
# [DCGAN] Epoch 13/30 | Train D Loss 0.9220 | Train G Loss 1.5401
# [DCGAN] Epoch 14/30 | Train D Loss 0.8927 | Train G Loss 1.5835
# [DCGAN] Epoch 15/30 | Train D Loss 0.8747 | Train G Loss 1.6202
# [DCGAN] Epoch 16/30 | Train D Loss 0.8669 | Train G Loss 1.6454
# [DCGAN] Epoch 17/30 | Train D Loss 0.8839 | Train G Loss 1.6424
# [DCGAN] Epoch 18/30 | Train D Loss 0.8443 | Train G Loss 1.6875
# [DCGAN] Epoch 19/30 | Train D Loss 0.8224 | Train G Loss 1.7349
# [DCGAN] Epoch 20/30 | Train D Loss 0.8174 | Train G Loss 1.7523
# [DCGAN] Epoch 21/30 | Train D Loss 0.8219 | Train G Loss 1.7618
# [DCGAN] Epoch 22/30 | Train D Loss 0.8070 | Train G Loss 1.7963
# [DCGAN] Epoch 23/30 | Train D Loss 0.7770 | Train G Loss 1.8529
# [DCGAN] Epoch 24/30 | Train D Loss 0.7836 | Train G Loss 1.8573
# [DCGAN] Epoch 25/30 | Train D Loss 0.7791 | Train G Loss 1.8738
# [DCGAN] Epoch 26/30 | Train D Loss 0.7800 | Train G Loss 1.8833
# [DCGAN] Epoch 27/30 | Train D Loss 0.7523 | Train G Loss 1.9182
# [DCGAN] Epoch 28/30 | Train D Loss 0.7569 | Train G Loss 1.9306
# [DCGAN] Epoch 29/30 | Train D Loss 0.7481 | Train G Loss 1.9560
# [DCGAN] Epoch 30/30 | Train D Loss 0.7166 | Train G Loss 2.0046

# %% [markdown]
# **DCGAN Sampling 시각화**

# %%
G.eval()

with torch.no_grad():

    z = torch.randn(64,latent_size,1,1).to(device)

    samples = G(z)

grid = make_grid(samples,8,normalize=True)

plt.imshow(grid.permute(1,2,0).cpu())
plt.title("DCGAN Samples")
plt.axis("off")
plt.show()

# %% [markdown]
# ## **🙋 [GAN] Question 2-1**
# VAE와 DCGAN으로 MNIST 이미지를 생성한 결과 VAE는 흐릿한 이미지, DCGAN은 선명한 이미지가 생성된 것을 알 수 있습니다. 그 이유를 VAE와 GAN의 특징과 학습 방식을 포함하여 설명해주세요.
#
# VAE는 데이터를 확률 분포로 근사하며, 손실 함수로 MSE나 BCE를 사용합니다. 이는 픽셀 간의 평균적인 차이를 줄이려 하기 때문에, 모델이 불확실한 부분을 출력할 때 여러 가능성을 평균 내어 흐릿하게 표현됩니다.
# 반면 GAN의 생성자는 판별자를 속이기 위해 실제 데이터의 미세한 특징과 질감을 정교하게 흉내 냅니다. 이를 위해 픽셀 값의 평균을 맞추는 것이 아니라 진짜처럼 보이기 위해 훨씬 선명하고 날카로운 이미지가 생성합니다.

# %% [markdown]
# ## **🙋 [GAN] Question 2-2**
# GAN 학습 과정에서 Generator의 Loss가 증가하는 것이 반드시 모델 성능 악화를 의미하지 않는 이유는 무엇인지 설명해주세요.
#
# GAN의 Loss는 절대적인 품질 지표가 아닙니다. 생성자의 Loss가 높다는 것은 현재 판별자가 매우 똑똑해져서 생성자의 가짜 이미지를 잘 잡아내고 있다는 뜻입니다.
# 판별자가 강력해지면 생성자 또한 속이기 위해 더 정교해집니다. 즉, 판별자가 생성자를 강하게 밀어붙이는 과정에서 생성자의 Loss는 일시적으로 상승할 수 있으며, 이는 오히려 판별자가 발전할 수 있는 학습 동기부여가 됩니다.

# %% [markdown]
# 수고하셨습니다 ☺️
